# %% [markdown]
# <a href="https://colab.research.google.com/github/indira19/etg_internship_project/blob/main/products_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
    products = { 100 : { 'product_name' : 'Diary Milk', 'quantity' : 20, 'expiry_date' : '10/10/2021', 'price' : 10 , 'weight' : '50g'},
            101 : { 'product_name' : '5 Star', 'quantity' : 30, 'expiry_date' : '22/11/2021', 'price' : 15 , 'weight' : '100g'},
            102 : { 'product_name' : 'Milkybar', 'quantity' : 35, 'expiry_date' : '23/10/2021', 'price' : 10 , 'weight' : '150g'},
            103 : { 'product_name' : 'Gems', 'quantity' : 25, 'expiry_date' : '11/11/2021', 'price' : 25 , 'weight' : '200g'},
            104 : { 'product_name' : 'Kinder Joy', 'quantity' : 40, 'expiry_date' : '18/10/2021', 'price' : 20 , 'weight' : '50g'},
            105 : { 'product_name' : 'Bourbon', 'quantity' : 45, 'expiry_date' : '19/11/2021', 'price' : 25 , 'weight' : '100g'},
            106 : { 'product_name' : 'Nestle', 'quantity' : 15, 'expiry_date' : '20/10/2021', 'price' : 30 , 'weight' : '150g'},
            107 : { 'product_name' : 'Silk oreo', 'quantity' : 20, 'expiry_date' : '14/11/2021', 'price' : 35 , 'weight' : '200g'},
            108 : { 'product_name' : 'Silk red velvet', 'quantity' : 5, 'expiry_date' : '15/10/2021', 'price' : 20 , 'weight' : '50g'},
            109 : { 'product_name' : 'Silk roasted almonds', 'quantity' : 10, 'expiry_date' : '16/11/2021', 'price' : 35 , 'weight' : '100g'},
            110 : { 'product_name' : 'Silk', 'quantity' : 45, 'expiry_date' : '17/10/2021', 'price' : 10 , 'weight' : '150g'},
            111 : { 'product_name' : 'Silk bubbly', 'quantity' : 22, 'expiry_date' : '18/11/2021', 'price' : 40 , 'weight' : '200g'},
            112 : { 'product_name' : 'Silk fruit & nuts', 'quantity' : 28, 'expiry_date' : '19/10/2021', 'price' : 60 , 'weight' : '50g'},
            113 : { 'product_name' : 'Milkybar chocolate', 'quantity' : 19, 'expiry_date' : '20/11/2021', 'price' : 75 , 'weight' : '100g'},
            114 : { 'product_name' : 'Milkybar strawberry', 'quantity' : 55, 'expiry_date' : '21/10/2021', 'price' : 25 , 'weight' : '150g'},
            115 : { 'product_name' : 'Milkybar orange', 'quantity' : 50, 'expiry_date' : '22/11/2021', 'price' : 35 , 'weight' : '200g'},
            116 : { 'product_name' : 'Diary Milk biscuit', 'quantity' : 45, 'expiry_date' : '23/10/2021', 'price' : 45 , 'weight' : '50g'},
            117 : { 'product_name' : 'Diary Milk caramel', 'quantity' : 35, 'expiry_date' : '24/11/2021', 'price' : 25 , 'weight' : '100g'},
            118 : { 'product_name' : 'Silk orange peel', 'quantity' : 49, 'expiry_date' : '25/10/2021', 'price' : 65 , 'weight' : '150g'},
            119 : { 'product_name' : 'Diary Milk ritz', 'quantity' : 52, 'expiry_date' : '26/11/2021', 'price' : 60 , 'weight' : '200g'},
            120 : { 'product_name' : 'Diary Milk rum & raisin', 'quantity' : 63, 'expiry_date' : '27/10/2021', 'price' : 55 , 'weight' : '50g'},
            121 : { 'product_name' : 'Double Decker', 'quantity' : 43, 'expiry_date' : '28/11/2021', 'price' : 50 , 'weight' : '100g'},
            122 : { 'product_name' : 'Dove Bar', 'quantity' : 32, 'expiry_date' : '29/11/2021', 'price' : 70 , 'weight' : '150g'},
            123 : { 'product_name' : 'Drifter', 'quantity' : 67, 'expiry_date' : '30/10/2021', 'price' : 75 , 'weight' : '200g'},
            124 : { 'product_name' : 'Flake', 'quantity' : 54, 'expiry_date' : '10/12/2021', 'price' : 80 , 'weight' : '50g'},
            125 : { 'product_name' : 'Fudge', 'quantity' : 41, 'expiry_date' : '17/12/2021', 'price' : 85 , 'weight' : '100g'},
            126 : { 'product_name' : 'Freddo', 'quantity' : 38, 'expiry_date' : '19/12/2021', 'price' : 90 , 'weight' : '150g'},
            127 : { 'product_name' : 'Galaxy', 'quantity' : 36, 'expiry_date' : '21/12/2021', 'price' : 95 , 'weight' : '200g'},
            128 : { 'product_name' : 'Galaxy caramel', 'quantity' : 19, 'expiry_date' : '23/12/2021', 'price' : 100 , 'weight' : '50g'},
            129 : { 'product_name' : 'Galaxy ripple', 'quantity' : 91, 'expiry_date' : '25/12/2021', 'price' : 110 , 'weight' : '100g'}
          }

# %%
products
# Out:
# {100: {'expiry_date': '10/10/2021',
#   'price': 10,
#   'product_name': 'Diary Milk',
#   'quantity': 20,
#   'weight': '50g'},
#  101: {'expiry_date': '22/11/2021',
#   'price': 15,
#   'product_name': '5 Star',
#   'quantity': 30,
#   'weight': '100g'},
#  102: {'expiry_date': '23/10/2021',
#   'price': 10,
#   'product_name': 'Milkybar',
#   'quantity': 35,
#   'weight': '150g'},
#  103: {'expiry_date': '11/11/2021',
#   'price': 25,
#   'product_name': 'Gems',
#   'quantity': 25,
#   'weight': '200g'},
#  104: {'expiry_date': '18/10/2021',
#   'price': 20,
#   'product_name': 'Kinder Joy',
#   'quantity': 40,
#   'weight': '50g'},
#  105: {'expiry_date': '19/11/2021',
#   'price': 25,
#   'product_name': 'Bourbon',
#   'quantity': 45,
#   'weight': '100g'},
#  106: {'expiry_date': '20/10/2021',
#   'price': 30,
#   'product_name': 'Nestle',
#   'quantity': 15,
#   'weight': '150g'},
#  107: {'expiry_date': '14/11/2021',
#   'price': 35,
#   'product_name': 'Silk oreo',
# ...

# %%
import json
js=json.dumps(products)
js
# Out:
# '{"100": {"product_name": "Diary Milk", "quantity": 20, "expiry_date": "10/10/2021", "price": 10, "weight": "50g"}, "101": {"product_name": "5 Star", "quantity": 30, "expiry_date": "22/11/2021", "price": 15, "weight": "100g"}, "102": {"product_name": "Milkybar", "quantity": 35, "expiry_date": "23/10/2021", "price": 10, "weight": "150g"}, "103": {"product_name": "Gems", "quantity": 25, "expiry_date": "11/11/2021", "price": 25, "weight": "200g"}, "104": {"product_name": "Kinder Joy", "quantity": 40, "expiry_date": "18/10/2021", "price": 20, "weight": "50g"}, "105": {"product_name": "Bourbon", "quantity": 45, "expiry_date": "19/11/2021", "price": 25, "weight": "100g"}, "106": {"product_name": "Nestle", "quantity": 15, "expiry_date": "20/10/2021", "price": 30, "weight": "150g"}, "107": {"product_name": "Silk oreo", "quantity": 20, "expiry_date": "14/11/2021", "price": 35, "weight": "200g"}, "108": {"product_name": "Silk red velvet", "quantity": 5, "expiry_date": "15/10/2021", "price": 20
# ...

# %%
fd = open('products.json','w')
fd.write(js)
fd.close()
fd = open('products.json','r')
txt = fd.read()
fd.close()
products = json.loads(txt)

# %%
txt
# Out:
# '{"100": {"product_name": "Diary Milk", "quantity": 20, "expiry_date": "10/10/2021", "price": 10, "weight": "50g"}, "101": {"product_name": "5 Star", "quantity": 30, "expiry_date": "22/11/2021", "price": 15, "weight": "100g"}, "102": {"product_name": "Milkybar", "quantity": 35, "expiry_date": "23/10/2021", "price": 10, "weight": "150g"}, "103": {"product_name": "Gems", "quantity": 25, "expiry_date": "11/11/2021", "price": 25, "weight": "200g"}, "104": {"product_name": "Kinder Joy", "quantity": 40, "expiry_date": "18/10/2021", "price": 20, "weight": "50g"}, "105": {"product_name": "Bourbon", "quantity": 45, "expiry_date": "19/11/2021", "price": 25, "weight": "100g"}, "106": {"product_name": "Nestle", "quantity": 15, "expiry_date": "20/10/2021", "price": 30, "weight": "150g"}, "107": {"product_name": "Silk oreo", "quantity": 20, "expiry_date": "14/11/2021", "price": 35, "weight": "200g"}, "108": {"product_name": "Silk red velvet", "quantity": 5, "expiry_date": "15/10/2021", "price": 20
# ...

# %%
products
# Out:
# {'100': {'expiry_date': '10/10/2021',
#   'price': 10,
#   'product_name': 'Diary Milk',
#   'quantity': 20,
#   'weight': '50g'},
#  '101': {'expiry_date': '22/11/2021',
#   'price': 15,
#   'product_name': '5 Star',
#   'quantity': 30,
#   'weight': '100g'},
#  '102': {'expiry_date': '23/10/2021',
#   'price': 10,
#   'product_name': 'Milkybar',
#   'quantity': 35,
#   'weight': '150g'},
#  '103': {'expiry_date': '11/11/2021',
#   'price': 25,
#   'product_name': 'Gems',
#   'quantity': 25,
#   'weight': '200g'},
#  '104': {'expiry_date': '18/10/2021',
#   'price': 20,
#   'product_name': 'Kinder Joy',
#   'quantity': 40,
#   'weight': '50g'},
#  '105': {'expiry_date': '19/11/2021',
#   'price': 25,
#   'product_name': 'Bourbon',
#   'quantity': 45,
#   'weight': '100g'},
#  '106': {'expiry_date': '20/10/2021',
#   'price': 30,
#   'product_name': 'Nestle',
#   'quantity': 15,
#   'weight': '150g'},
#  '107': {'expiry_date': '14/11/2021',
#   'price': 35,
# ...
