# %%
import json
fd = open("record.json",'r')
r = fd.read()
fd.close()
records = json.loads(r)

# %%
records
# Out:
# {'100': {'expiry_date': '10/10/2021',
#   'price': 10,
#   'product_name': 'Diary Milk',
#   'quantity': 20,
#   'weight': '50g'},
#  '101': {'expiry_date': '22/11/2021',
#   'price': 15,
#   'product_name': '5 Star',
#   'quantity': 30,
#   'weight': '100g'},
#  '102': {'expiry_date': '23/10/2021',
#   'price': 10,
#   'product_name': 'Milkybar',
#   'quantity': 35,
#   'weight': '150g'},
#  '103': {'expiry_date': '11/11/2021',
#   'price': 25,
#   'product_name': 'Gems',
#   'quantity': 25,
#   'weight': '200g'},
#  '104': {'expiry_date': '18/10/2021',
#   'price': 20,
#   'product_name': 'Kinder Joy',
#   'quantity': 40,
#   'weight': '50g'},
#  '105': {'expiry_date': '19/11/2021',
#   'price': 25,
#   'product_name': 'Bourbon',
#   'quantity': 45,
#   'weight': '100g'},
#  '106': {'expiry_date': '20/10/2021',
#   'price': 30,
#   'product_name': 'Nestle',
#   'quantity': 15,
#   'weight': '150g'},
#  '107': {'expiry_date': '14/11/2021',
#   'price': 35,
#   'product_name': 'Silk oreo',
#   'quantity': 20,
#   'weight': '200g'},
#  '108': {'expiry_date': '15/10/2021',
#   'price': 20,
#   'product_name': 'Silk red velvet',
#   'quantity': 5,
#   'weight': '50g'},
#  '109': {'expiry_date': '16/11/2021',
#   'price': 35,
#   'product_name': 'Silk roasted almonds',
#   'quantity': 10,
#   'weight': '100g'},
#  '110': {'expiry_date': '17/10/2021',
#   'price': 10,
#   'product_name': 'Silk',
#   'quantity': 45,
#   'weight': '150g'},
#  '111': {'expiry_date': '18/11/2021',
#   'price': 40,
#   'product_name': 'Silk bubbly',
#   'quantity': 22,
#   'weight': '200g'},
#  '112': {'expiry_date': '19/10/2021',
#   'price': 60,
#   'product_name': 'Silk fruit & nuts',
#   'quantity': 28,
#   'weight': '50g'},
#  '113': {'expiry_date': '20/11/2021',
#   'price': 75,
#   'product_name': 'Milkybar chocolate',
#   'quantity': 19,
#   'weight': '100g'},
#  '114': {'expiry_date': '21/10/2021',
#   'price': 25,
#   'product_name': 'Milkybar strawberry',
#   'quantity': 55,
#   'weight': '150g'},
#  '115': {'expiry_date': '22/11/2021',
#   'price': 35,
#   'product_name': 'Milkybar orange',
#   'quantity': 50,
#   'weight': '200g'},
#  '116': {'expiry_date': '23/10/2021',
#   'price': 45,
#   'product_name': 'Diary Milk biscuit',
#   'quantity': 45,
#   'weight': '50g'},
#  '117': {'expiry_date': '24/11/2021',
#   'price': 25,
#   'product_name': 'Diary Milk caramel',
#   'quantity': 35,
#   'weight': '100g'},
#  '118': {'expiry_date': '25/10/2021',
#   'price': 65,
#   'product_name': 'Silk orange peel',
#   'quantity': 49,
#   'weight': '150g'},
#  '119': {'expiry_date': '26/11/2021',
#   'price': 60,
#   'product_name': 'Diary Milk ritz',
#   'quantity': 52,
#   'weight': '200g'},
#  '120': {'expiry_date': '27/10/2021',
#   'price': 55,
#   'product_name': 'Diary Milk rum & raisin',
#   'quantity': 63,
#   'weight': '50g'},
#  '121': {'expiry_date': '28/11/2021',
#   'price': 50,
#   'product_name': 'Double Decker',
#   'quantity': 43,
#   'weight': '100g'},
#  '122': {'expiry_date': '29/11/2021',
#   'price': 70,
#   'product_name': 'Dove Bar',
#   'quantity': 32,
#   'weight': '150g'},
#  '123': {'expiry_date': '30/10/2021',
#   'price': 75,
#   'product_name': 'Drifter',
#   'quantity': 67,
#   'weight': '200g'},
#  '124': {'expiry_date': '10/12/2021',
#   'price': 80,
#   'product_name': 'Flake',
#   'quantity': 54,
#   'weight': '50g'},
#  '125': {'expiry_date': '17/12/2021',
#   'price': 85,
#   'product_name': 'Fudge',
#   'quantity': 41,
#   'weight': '100g'},
#  '126': {'expiry_date': '19/12/2021',
#   'price': 90,
#   'product_name': 'Freddo',
#   'quantity': 38,
#   'weight': '150g'},
#  '127': {'expiry_date': '21/12/2021',
#   'price': 95,
#   'product_name': 'Galaxy',
#   'quantity': 36,
#   'weight': '200g'},
#  '128': {'expiry_date': '23/12/2021',
#   'price': 100,
#   'product_name': 'Galaxy caramel',
#   'quantity': 19,
#   'weight': '50g'},
#  '129': {'expiry_date': '25/12/2021',
#   'price': 110,
#   'product_name': 'Galaxy ripple',
#   'quantity': 91,
#   'weight': '100g'}}

# %%
prod_id = input("Enter Product id:")
name = input("Enter name:")
qn = int(input("Enter quantity:"))
wgt = input("Enter Weight:")
exp = input("Enter expiry date:")
pr = int(input("Enter Price:"))

records[prod_id] = {'product_name': name, 'quantity': qn, 'expiry_date': exp, 'weight':wgt, 'price':pr}


js = json.dumps(records)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter Product id:130
# Enter name:Lindt
# Enter quantity:25
# Enter Weight:120g
# Enter expiry date:12/12/2022
# Enter Price:180

# %%
records
# Out:
# {'100': {'expiry_date': '10/10/2021',
#   'price': 10,
#   'product_name': 'Diary Milk',
#   'quantity': 20,
#   'weight': '50g'},
#  '101': {'expiry_date': '22/11/2021',
#   'price': 15,
#   'product_name': '5 Star',
#   'quantity': 30,
#   'weight': '100g'},
#  '102': {'expiry_date': '23/10/2021',
#   'price': 10,
#   'product_name': 'Milkybar',
#   'quantity': 35,
#   'weight': '150g'},
#  '103': {'expiry_date': '11/11/2021',
#   'price': 25,
#   'product_name': 'Gems',
#   'quantity': 25,
#   'weight': '200g'},
#  '104': {'expiry_date': '18/10/2021',
#   'price': 20,
#   'product_name': 'Kinder Joy',
#   'quantity': 40,
#   'weight': '50g'},
#  '105': {'expiry_date': '19/11/2021',
#   'price': 25,
#   'product_name': 'Bourbon',
#   'quantity': 45,
#   'weight': '100g'},
#  '106': {'expiry_date': '20/10/2021',
#   'price': 30,
#   'product_name': 'Nestle',
#   'quantity': 15,
#   'weight': '150g'},
#  '107': {'expiry_date': '14/11/2021',
#   'price': 35,
#   'product_name': 'Silk oreo',
#   'quantity': 20,
#   'weight': '200g'},
#  '108': {'expiry_date': '15/10/2021',
#   'price': 20,
#   'product_name': 'Silk red velvet',
#   'quantity': 5,
#   'weight': '50g'},
#  '109': {'expiry_date': '16/11/2021',
#   'price': 35,
#   'product_name': 'Silk roasted almonds',
#   'quantity': 10,
#   'weight': '100g'},
#  '110': {'expiry_date': '17/10/2021',
#   'price': 10,
#   'product_name': 'Silk',
#   'quantity': 45,
#   'weight': '150g'},
#  '111': {'expiry_date': '18/11/2021',
#   'price': 40,
#   'product_name': 'Silk bubbly',
#   'quantity': 22,
#   'weight': '200g'},
#  '112': {'expiry_date': '19/10/2021',
#   'price': 60,
#   'product_name': 'Silk fruit & nuts',
#   'quantity': 28,
#   'weight': '50g'},
#  '113': {'expiry_date': '20/11/2021',
#   'price': 75,
#   'product_name': 'Milkybar chocolate',
#   'quantity': 19,
#   'weight': '100g'},
#  '114': {'expiry_date': '21/10/2021',
#   'price': 25,
#   'product_name': 'Milkybar strawberry',
#   'quantity': 55,
#   'weight': '150g'},
#  '115': {'expiry_date': '22/11/2021',
#   'price': 35,
#   'product_name': 'Milkybar orange',
#   'quantity': 50,
#   'weight': '200g'},
#  '116': {'expiry_date': '23/10/2021',
#   'price': 45,
#   'product_name': 'Diary Milk biscuit',
#   'quantity': 45,
#   'weight': '50g'},
#  '117': {'expiry_date': '24/11/2021',
#   'price': 25,
#   'product_name': 'Diary Milk caramel',
#   'quantity': 35,
#   'weight': '100g'},
#  '118': {'expiry_date': '25/10/2021',
#   'price': 65,
#   'product_name': 'Silk orange peel',
#   'quantity': 49,
#   'weight': '150g'},
#  '119': {'expiry_date': '26/11/2021',
#   'price': 60,
#   'product_name': 'Diary Milk ritz',
#   'quantity': 52,
#   'weight': '200g'},
#  '120': {'expiry_date': '27/10/2021',
#   'price': 55,
#   'product_name': 'Diary Milk rum & raisin',
#   'quantity': 63,
#   'weight': '50g'},
#  '121': {'expiry_date': '28/11/2021',
#   'price': 50,
#   'product_name': 'Double Decker',
#   'quantity': 43,
#   'weight': '100g'},
#  '122': {'expiry_date': '29/11/2021',
#   'price': 70,
#   'product_name': 'Dove Bar',
#   'quantity': 32,
#   'weight': '150g'},
#  '123': {'expiry_date': '30/10/2021',
#   'price': 75,
#   'product_name': 'Drifter',
#   'quantity': 67,
#   'weight': '200g'},
#  '124': {'expiry_date': '10/12/2021',
#   'price': 80,
#   'product_name': 'Flake',
#   'quantity': 54,
#   'weight': '50g'},
#  '125': {'expiry_date': '17/12/2021',
#   'price': 85,
#   'product_name': 'Fudge',
#   'quantity': 41,
#   'weight': '100g'},
#  '126': {'expiry_date': '19/12/2021',
#   'price': 90,
#   'product_name': 'Freddo',
#   'quantity': 38,
#   'weight': '150g'},
#  '127': {'expiry_date': '21/12/2021',
#   'price': 95,
#   'product_name': 'Galaxy',
#   'quantity': 36,
#   'weight': '200g'},
#  '128': {'expiry_date': '23/12/2021',
#   'price': 100,
#   'product_name': 'Galaxy caramel',
#   'quantity': 19,
#   'weight': '50g'},
#  '129': {'expiry_date': '25/12/2021',
#   'price': 110,
#   'product_name': 'Galaxy ripple',
#   'quantity': 91,
#   'weight': '100g'},
#  '130': {'expiry_date': '12/12/2022',
#   'price': 180,
#   'product_name': 'Lindt',
#   'quantity': 25,
#   'weight': '120g'}}
